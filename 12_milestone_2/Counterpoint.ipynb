# %% [markdown]
# ## Milestone 2

# %%
display.Image("./stevie.png")

# %%
display.Image("./additive.png")

# %%
display.Image("./seq.png")

# %%
display.Image("./voices.png")

# %%
display.Image("./voice_pl.png")
